# %%
# %%html
# <style> h1, h2, h3, h4 {font-weight: normal !important} </style>
# Out:
# <style> h1, h2, h3, h4 {font-weight: normal !important} </style>

# %%
# imports

import copy
import time
from pathlib import Path

import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import timm
import torch
from torchvision import models, datasets, transforms
from tqdm import tqdm

# %%
# config

device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f"using {device}")

# runs depending on platform

if Path("/kaggle/input").exists():
    platform = "kaggle"
    input_dir = Path("/kaggle/input/")
    save_dir = Path("/kaggle/output/")
else:
    platform = "local"
    input_dir = Path("./dataset/")
    save_dir = Path("./results/")
    
print(f"script running on {platform}")

random_seed = 13
print(f"using random seed: {random_seed}")
# Out:
# using cuda:0
# script running on local
# using random seed: 13

# %% [markdown]
# ## Transforms

# %%
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomRotation(30),
        transforms.CenterCrop(224),
#         transforms.Resize(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#         transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
    "valid": transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %% [markdown]
# ## DataLoaders

# %%
list(input_dir.iterdir())
# Out:
# [PosixPath('dataset/train.csv'),
#  PosixPath('dataset/test_images'),
#  PosixPath('dataset/sample_submission.csv'),
#  PosixPath('dataset/train_images')]

# %%
train_images_dir = input_dir/"train_images"
all_train_images = train_images_dir.glob("*/*")

test_images_dir = input_dir/"test_images"
all_test_images = test_images_dir.iterdir()

# %%
def create_df(images_gen, train=True):
    df = pd.DataFrame(list(images_gen), columns=["path"])
    if train:
        df["category"] = df.path.apply(lambda x: x.parent.name)
        le = LabelEncoder()
        df["encoded_label"] = le.fit_transform(df.category)
    return df

# %%
df = create_df(all_train_images)
df.head()
# Out:
#                                                 path               category  \
# 0  dataset/train_images/bacterial_leaf_streak/107...  bacterial_leaf_streak
# 1  dataset/train_images/bacterial_leaf_streak/101...  bacterial_leaf_streak
# 2  dataset/train_images/bacterial_leaf_streak/104...  bacterial_leaf_streak
# 3  dataset/train_images/bacterial_leaf_streak/100...  bacterial_leaf_streak
# 4  dataset/train_images/bacterial_leaf_streak/104...  bacterial_leaf_streak
#
#    encoded_label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# split train and test
x_train, x_valid = train_test_split(df, test_size=0.2, shuffle=True, stratify=df.encoded_label, random_state=random_seed)
x_train.shape, x_valid.shape
# Out:
# ((8325, 3), (2082, 3))

# %%
class MakeDataset(torch.utils.data.Dataset):
    
    def __init__(self, df, transform=None):
        self.df = df
        self.images = df.path.values
        self.labels = df.encoded_label.values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        image_path, label = self.images[idx], self.labels[idx]
        if self.transform:
            img = Image.open(image_path)
            img = self.transform(img)
        return img, label

# %%
trainset = MakeDataset(x_train, transform=data_transforms["train"])
validset = MakeDataset(x_valid, transform=data_transforms["valid"])

# %%
train_dl = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=4)
valid_dl = torch.utils.data.DataLoader(validset, batch_size=16, shuffle=True, num_workers=4)

# %% [markdown]
# ## Model build

# %%
# model = models.resnet18()
# num_ftrs = model.fc.in_features
# model.fc = torch.nn.Linear(num_ftrs, 10)
# model = model.to(device)

# %%
model = timm.create_model("levit_384", pretrained=True, num_classes=10)
model = model.to(device)
# Out:
# /home/tharun/.conda/envs/torch/lib/python3.10/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484803030/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# define loss
criterion = torch.nn.CrossEntropyLoss()

# %%
# define optimizer
optim = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

# %%
# define lr_scheduler
lr_sch = torch.optim.lr_scheduler.ReduceLROnPlateau(optim, factor=0.1, patience=5)

# %% [markdown]
# ### Train the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=100):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f"epoch: {epoch}")
        print("-" * 10)

        running_loss = 0.0
        total_corrects = 0
        # train phase
        for i, (inputs, labels) in enumerate(train_dl):
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            total_corrects += torch.sum(predicted==labels.data)
        # print stats
        print(f"loss: {running_loss/len(x_train):.8f}")
        print(f"training acc: {total_corrects/len(x_train):.2f}")

        # validation phase
        total_corrects = 0
        running_loss = 0
        for i, (inputs, labels) in enumerate(valid_dl):
            with torch.no_grad():
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                total_corrects += torch.sum(predicted==labels.data)
        epoch_valid_acc = total_corrects/len(x_valid)
        epoch_valid_loss = running_loss/len(x_valid)
        scheduler.step(epoch_valid_loss)
        
        print(f"valid acc: {epoch_valid_acc:.2f}")

        if epoch_valid_acc > best_acc:
            best_acc = epoch_valid_acc
            best_model_wts = copy.deepcopy(model.state_dict())
        
        print("\n")

    elapsed_time = time.time() - since
    print(f"total time taken: {elapsed_time/60:0f}m {elapsed_time%60:0f}s")
    print(f"best accuracy: {best_acc}")
    return model.load_state_dict(best_model_wts)

# %%
model = train_model(model, criterion, optim, lr_sch)
# Out:
# epoch: 0
# ----------
# loss: 1.85536091
# training acc: 0.37
# valid acc: 0.40
#
#
# epoch: 1
# ----------
# loss: 1.28523064
# training acc: 0.57
# valid acc: 0.52
#
#
# epoch: 2
# ----------
# loss: 0.99486742
# training acc: 0.67
# valid acc: 0.57
#
#
# epoch: 3
# ----------
# loss: 0.80823612
# training acc: 0.73
# valid acc: 0.64
#
#
# epoch: 4
# ----------
# loss: 0.66237168
# training acc: 0.79
# valid acc: 0.63
#
#
# epoch: 5
# ----------
# loss: 0.54387833
# training acc: 0.83
# valid acc: 0.65
#
#
# epoch: 6
# ----------
# loss: 0.48159271
# training acc: 0.84
# valid acc: 0.66
#
#
# epoch: 7
# ----------
# loss: 0.39446288
# training acc: 0.87
# valid acc: 0.68
#
#
# epoch: 8
# ----------
# loss: 0.34267245
# training acc: 0.89
# valid acc: 0.69
#
#
# epoch: 9
# ----------
# loss: 0.32254438
# training acc: 0.89
# valid acc: 0.74
#
#
# epoch: 10
# ----------
# loss: 0.26956554
# training acc: 0.91
# valid acc: 0.72
#
#
# epoch: 11
# ----------
# loss: 0.24496070
# training acc: 0.92
# valid acc: 0.71
#
#
# epoch: 12
# ----------
# loss: 0.20751811
# training acc: 0.93
# valid acc: 0.73
#
#
# epoch: 13
# ----------
# loss: 0.19202270
# training acc: 0.94
# valid acc: 0.73
#
#
# epoch: 14
# ----------
# loss: 0.17072472
# training acc: 0.94
# valid acc: 0.73
#
#
# epoch: 15
# ----------
# loss: 0.15163500
# training acc: 0.95
# valid acc: 0.77
#
#
# epoch: 16
# ----------
# loss: 0.13467221
# training acc: 0.96
# valid acc: 0.76
#
#
# epoch: 17
# ----------
# loss: 0.13394301
# training acc: 0.96
# valid acc: 0.74
#
#
# epoch: 18
# ----------
# loss: 0.11485038
# training acc: 0.96
# valid acc: 0.76
#
#
# epoch: 19
# ----------
# loss: 0.11411685
# training acc: 0.96
# valid acc: 0.76
#
#
# epoch: 20
# ----------
# loss: 0.09310518
# training acc: 0.97
# valid acc: 0.74
#
#
# epoch: 21
# ----------
# loss: 0.11048553
# training acc: 0.96
# valid acc: 0.76
#
#
# epoch: 22
# ----------
# loss: 0.06159141
# training acc: 0.98
# valid acc: 0.79
#
#
# epoch: 23
# ----------
# loss: 0.03856554
# training acc: 0.99
# valid acc: 0.80
#
#
# epoch: 24
# ----------
# loss: 0.03100389
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 25
# ----------
# loss: 0.02864149
# training acc: 0.99
# valid acc: 0.80
#
#
# epoch: 26
# ----------
# loss: 0.02877874
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 27
# ----------
# loss: 0.02322941
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 28
# ----------
# loss: 0.02393225
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 29
# ----------
# loss: 0.02179061
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 30
# ----------
# loss: 0.02067103
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 31
# ----------
# loss: 0.02002000
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 32
# ----------
# loss: 0.01814057
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 33
# ----------
# loss: 0.02010719
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 34
# ----------
# loss: 0.01787003
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 35
# ----------
# loss: 0.01419354
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 36
# ----------
# loss: 0.01422290
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 37
# ----------
# loss: 0.01755182
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 38
# ----------
# loss: 0.01350028
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 39
# ----------
# loss: 0.01570438
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 40
# ----------
# loss: 0.01610460
# training acc: 0.99
# valid acc: 0.83
#
#
# epoch: 41
# ----------
# loss: 0.01594620
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 42
# ----------
# loss: 0.01167014
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 43
# ----------
# loss: 0.01330450
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 44
# ----------
# loss: 0.01259212
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 45
# ----------
# loss: 0.01361058
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 46
# ----------
# loss: 0.01463282
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 47
# ----------
# loss: 0.01138315
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 48
# ----------
# loss: 0.01049402
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 49
# ----------
# loss: 0.01190770
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 50
# ----------
# loss: 0.01027317
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 51
# ----------
# loss: 0.01181959
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 52
# ----------
# loss: 0.01519784
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 53
# ----------
# loss: 0.01534455
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 54
# ----------
# loss: 0.01160935
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 55
# ----------
# loss: 0.01555534
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 56
# ----------
# loss: 0.01351699
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 57
# ----------
# loss: 0.01175841
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 58
# ----------
# loss: 0.01461658
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 59
# ----------
# loss: 0.01294050
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 60
# ----------
# loss: 0.01160917
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 61
# ----------
# loss: 0.01197811
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 62
# ----------
# loss: 0.01287313
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 63
# ----------
# loss: 0.01309638
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 64
# ----------
# loss: 0.01302037
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 65
# ----------
# loss: 0.01176928
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 66
# ----------
# loss: 0.01094992
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 67
# ----------
# loss: 0.01206133
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 68
# ----------
# loss: 0.01153874
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 69
# ----------
# loss: 0.01197641
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 70
# ----------
# loss: 0.01328022
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 71
# ----------
# loss: 0.01329925
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 72
# ----------
# loss: 0.01375275
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 73
# ----------
# loss: 0.01155682
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 74
# ----------
# loss: 0.01269473
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 75
# ----------
# loss: 0.01152714
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 76
# ----------
# loss: 0.01257474
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 77
# ----------
# loss: 0.01315341
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 78
# ----------
# loss: 0.01300367
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 79
# ----------
# loss: 0.01257033
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 80
# ----------
# loss: 0.00990988
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 81
# ----------
# loss: 0.01293799
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 82
# ----------
# loss: 0.01112127
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 83
# ----------
# loss: 0.01339354
# training acc: 0.99
# valid acc: 0.83
#
#
# epoch: 84
# ----------
# loss: 0.01179868
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 85
# ----------
# loss: 0.01147663
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 86
# ----------
# loss: 0.01104671
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 87
# ----------
# loss: 0.01393250
# training acc: 0.99
# valid acc: 0.81
#
#
# epoch: 88
# ----------
# loss: 0.01149891
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 89
# ----------
# loss: 0.01200019
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 90
# ----------
# loss: 0.01432939
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 91
# ----------
# loss: 0.01295993
# training acc: 0.99
# valid acc: 0.82
#
#
# epoch: 92
# ----------
# loss: 0.01204043
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 93
# ----------
# loss: 0.01168992
# training acc: 1.00
# valid acc: 0.83
#
#
# epoch: 94
# ----------
# loss: 0.01182737
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 95
# ----------
# loss: 0.01437417
# training acc: 0.99
# valid acc: 0.80
#
#
# epoch: 96
# ----------
# loss: 0.01243081
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 97
# ----------
# loss: 0.01165560
# training acc: 1.00
# valid acc: 0.81
#
#
# epoch: 98
# ----------
# loss: 0.01313750
# training acc: 1.00
# valid acc: 0.82
#
#
# epoch: 99
# ----------
# loss: 0.01186122
# training acc: 1.00
# valid acc: 0.82
#
#
# total time taken: 36.834527m 50.071615s
# best accuracy: 0.8323726654052734

# %% [markdown]
# ## Inference

# %%
test_df = create_df(all_test_images, train=False)
test_df.head()
# Out:
#                              path
# 0  dataset/test_images/200761.jpg
# 1  dataset/test_images/201036.jpg
# 2  dataset/test_images/201042.jpg
# 3  dataset/test_images/203280.jpg
# 4  dataset/test_images/200126.jpg

# %%
test_df["label"] = None
model.eval()

for key, value in test_df.path.items():
    img = Image.open(value)
    img = data_transforms["valid"](img)
    img = img.unsqueeze(0).to(device)
    prediction = model(img).argmax().item()
    label = le.inverse_transform([prediction])[0]
    test_df.loc[key, "label"] = label

test_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 test_df["label"] = None
# ----> 2 model.eval()
#       4 for key, value in test_df.path.items():
#       5     img = Image.open(value)
#
# AttributeError: '_IncompatibleKeys' object has no attribute 'eval'

# %%
subm_df = test_df.copy(deep=True)
subm_df["image_id"] = subm_df.path.apply(lambda x: x.name)

subm_df.drop("path", axis=1, inplace=True)
subm_df.to_csv(save_dir/"levit384.csv", index=False)

# %%
subm_df.label.value_counts()
